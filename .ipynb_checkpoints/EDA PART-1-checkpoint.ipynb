# %% [markdown]
# # Importing required libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Loading the dataset

# %%
df = pd.read_csv("data.csv",encoding = 'ISO-8859-1')

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12/9/2011 12:50       0.85     12680.0          France
# 541905  12/9/2011 12:50       2.10     12680.0          France
# 541906  12/9/2011 12:50       4.15     12680.0          France
# 541907  12/9/2011 12:50       4.15     12680.0          France
# 541908  12/9/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
df.shape
# Out:
# (541909, 8)

# %% [markdown]
# # Access first 5 rows

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# # Access last 5 rows

# %%
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 541904  12/9/2011 12:50       0.85     12680.0  France
# 541905  12/9/2011 12:50       2.10     12680.0  France
# 541906  12/9/2011 12:50       4.15     12680.0  France
# 541907  12/9/2011 12:50       4.15     12680.0  France
# 541908  12/9/2011 12:50       4.95     12680.0  France

# %% [markdown]
# # list of all columns

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='str')

# %%
d={
    'InvoiceNo': 'invoice_num',
    'StockCode': 'stock_code',
    'Description': 'description',
    'Quantity': 'quantity',
    'InvoiceDate': 'invoice_date',
    'UnitPrice':'unit_price',
    'CustomerID': 'cust_id',
    'Country': 'country'
}

# %%
d
# Out:
# {'InvoiceNo': 'invoice_num',
#  'StockCode': 'stock_code',
#  'Description': 'description',
#  'Quantity': 'quantity',
#  'InvoiceDate': 'invoice_date',
#  'UnitPrice': 'unit_price',
#  'CustomerID': 'cust_id',
#  'Country': 'country'}

# %%
df.rename(columns=d,inplace=True)

# %% [markdown]
# # After renaming columns printing DataFrame

# %%
df
# Out:
#        invoice_num stock_code                          description  quantity  \
# 0           536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1           536365      71053                  WHITE METAL LANTERN         6
# 2           536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3           536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4           536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...            ...        ...                                  ...       ...
# 541904      581587      22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905      581587      22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906      581587      23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907      581587      23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908      581587      22138        BAKING SET 9 PIECE RETROSPOT          3
#
#            invoice_date  unit_price  cust_id         country
# 0        12/1/2010 8:26        2.55  17850.0  United Kingdom
# 1        12/1/2010 8:26        3.39  17850.0  United Kingdom
# 2        12/1/2010 8:26        2.75  17850.0  United Kingdom
# 3        12/1/2010 8:26        3.39  17850.0  United Kingdom
# 4        12/1/2010 8:26        3.39  17850.0  United Kingdom
# ...                 ...         ...      ...             ...
# 541904  12/9/2011 12:50        0.85  12680.0          France
# 541905  12/9/2011 12:50        2.10  12680.0          France
# 541906  12/9/2011 12:50        4.15  12680.0          France
# 541907  12/9/2011 12:50        4.15  12680.0          France
# 541908  12/9/2011 12:50        4.95  12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# # Lets check initial data or checking top 5 rows in DataFrame

# %%
df.head()
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      536365      71053                  WHITE METAL LANTERN         6
# 2      536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#      invoice_date  unit_price  cust_id         country
# 0  12/1/2010 8:26        2.55  17850.0  United Kingdom
# 1  12/1/2010 8:26        3.39  17850.0  United Kingdom
# 2  12/1/2010 8:26        2.75  17850.0  United Kingdom
# 3  12/1/2010 8:26        3.39  17850.0  United Kingdom
# 4  12/1/2010 8:26        3.39  17850.0  United Kingdom

# %% [markdown]
# # Data Cleaning operations

# %%
df.dtypes
# Out:
# invoice_num         str
# stock_code          str
# description         str
# quantity          int64
# invoice_date        str
# unit_price      float64
# cust_id         float64
# country             str
# dtype: object

# %%
"""
here what we can analyse from the dtypes is that:
    1.invoice data should be in datetime format
    2.generally cust_id should be integer
"""
# Out:
# '\nhere what we can analyse from the dtypes is that:\n    1.invoice data should be in datetime format\n    2.generally cust_id should be integer\n'

# %% [markdown]
# # DataFrame information

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_num   541909 non-null  str
#  1   stock_code    541909 non-null  str
#  2   description   540455 non-null  str
#  3   quantity      541909 non-null  int64
#  4   invoice_date  541909 non-null  str
#  5   unit_price    541909 non-null  float64
#  6   cust_id       406829 non-null  float64
#  7   country       541909 non-null  str
# dtypes: float64(2), int64(1), str(5)
# memory usage: 33.1 MB

# %% [markdown]
#  # description,cust_ID have some missing values.Therefore descripition was optional.But cust_id is missing which is a serious concern. i.e we have to do some R&D and ask to the data provider(client). why customers are missing.Eg:-There might be some vip ids whose data is hided"""

# %%
df.isna()
# Out:
#         invoice_num  stock_code  description  quantity  invoice_date  \
# 0             False       False        False     False         False
# 1             False       False        False     False         False
# 2             False       False        False     False         False
# 3             False       False        False     False         False
# 4             False       False        False     False         False
# ...             ...         ...          ...       ...           ...
# 541904        False       False        False     False         False
# 541905        False       False        False     False         False
# 541906        False       False        False     False         False
# 541907        False       False        False     False         False
# 541908        False       False        False     False         False
#
#         unit_price  cust_id  country
# 0            False    False    False
# 1            False    False    False
# 2            False    False    False
# 3            False    False    False
# 4            False    False    False
# ...            ...      ...      ...
# 541904       False    False    False
# 541905       False    False    False
# 541906       False    False    False
# 541907       False    False    False
# 541908       False    False    False
#
# [541909 rows x 8 columns]

# %%
df.isna().sum()
# Out:
# invoice_num          0
# stock_code           0
# description       1454
# quantity             0
# invoice_date         0
# unit_price           0
# cust_id         135080
# country              0
# dtype: int64

# %% [markdown]
# # we came to the conclusion of no of missing values

# %%
df.isna().sum().sort_values()
# Out:
# invoice_num          0
# stock_code           0
# quantity             0
# invoice_date         0
# country              0
# unit_price           0
# description       1454
# cust_id         135080
# dtype: int64

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# cust_id         135080
# description       1454
# stock_code           0
# invoice_num          0
# quantity             0
# invoice_date         0
# unit_price           0
# country              0
# dtype: int64

# %%
#this is how we have to reach out to client with data.by keeping most missed values at top

# %%
df.dtypes
# Out:
# invoice_num         str
# stock_code          str
# description         str
# quantity          int64
# invoice_date        str
# unit_price      float64
# cust_id         float64
# country             str
# dtype: object

# %%
df['invoice_date']=pd.to_datetime(df['invoice_date'],format='%m/%d/%Y %H:%M')

# %%
df.dtypes
# Out:
# invoice_num                str
# stock_code                 str
# description                str
# quantity                 int64
# invoice_date    datetime64[us]
# unit_price             float64
# cust_id                float64
# country                    str
# dtype: object

# %%
df.head(2)
# Out:
#   invoice_num stock_code                         description  quantity  \
# 0      536365     85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      536365      71053                 WHITE METAL LANTERN         6
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55  17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39  17850.0  United Kingdom

# %% [markdown]
# # we have sucesfully converted datetime coulum

# %%
df.description
# Out:
# 0          WHITE HANGING HEART T-LIGHT HOLDER
# 1                         WHITE METAL LANTERN
# 2              CREAM CUPID HEARTS COAT HANGER
# 3         KNITTED UNION FLAG HOT WATER BOTTLE
# 4              RED WOOLLY HOTTIE WHITE HEART.
#                          ...
# 541904            PACK OF 20 SPACEBOY NAPKINS
# 541905           CHILDREN'S APRON DOLLY GIRL
# 541906          CHILDRENS CUTLERY DOLLY GIRL
# 541907        CHILDRENS CUTLERY CIRCUS PARADE
# 541908          BAKING SET 9 PIECE RETROSPOT
# Name: description, Length: 541909, dtype: str

# %%
df.description.str.lower() #we need to convert description to lower case
# Out:
# 0          white hanging heart t-light holder
# 1                         white metal lantern
# 2              cream cupid hearts coat hanger
# 3         knitted union flag hot water bottle
# 4              red woolly hottie white heart.
#                          ...
# 541904            pack of 20 spaceboy napkins
# 541905           children's apron dolly girl
# 541906          childrens cutlery dolly girl
# 541907        childrens cutlery circus parade
# 541908          baking set 9 piece retrospot
# Name: description, Length: 541909, dtype: str

# %%
df.head()
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      536365      71053                  WHITE METAL LANTERN         6
# 2      536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55  17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39  17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75  17850.0  United Kingdom
# 3 2010-12-01 08:26:00        3.39  17850.0  United Kingdom
# 4 2010-12-01 08:26:00        3.39  17850.0  United Kingdom

# %%
df['description'] = df.description.str.lower()

# %%
df.head()
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   white hanging heart t-light holder         6
# 1      536365      71053                  white metal lantern         6
# 2      536365     84406B       cream cupid hearts coat hanger         8
# 3      536365     84029G  knitted union flag hot water bottle         6
# 4      536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55  17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39  17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75  17850.0  United Kingdom
# 3 2010-12-01 08:26:00        3.39  17850.0  United Kingdom
# 4 2010-12-01 08:26:00        3.39  17850.0  United Kingdom

# %% [markdown]
# # based on clint discussion team meating we need to perform action for missing values

# %%
df_new = df.dropna()

# %%
df_new.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_num   406829 non-null  str
#  1   stock_code    406829 non-null  str
#  2   description   406829 non-null  str
#  3   quantity      406829 non-null  int64
#  4   invoice_date  406829 non-null  datetime64[us]
#  5   unit_price    406829 non-null  float64
#  6   cust_id       406829 non-null  float64
#  7   country       406829 non-null  str
# dtypes: datetime64[us](1), float64(2), int64(1), str(4)
# memory usage: 27.9 MB

# %%
df.isna().sum()
# Out:
# invoice_num          0
# stock_code           0
# description       1454
# quantity             0
# invoice_date         0
# unit_price           0
# cust_id         135080
# country              0
# dtype: int64

# %%
df_new.isna().sum()
# Out:
# invoice_num     0
# stock_code      0
# description     0
# quantity        0
# invoice_date    0
# unit_price      0
# cust_id         0
# country         0
# dtype: int64

# %%
df_new.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_num   406829 non-null  str
#  1   stock_code    406829 non-null  str
#  2   description   406829 non-null  str
#  3   quantity      406829 non-null  int64
#  4   invoice_date  406829 non-null  datetime64[us]
#  5   unit_price    406829 non-null  float64
#  6   cust_id       406829 non-null  float64
#  7   country       406829 non-null  str
# dtypes: datetime64[us](1), float64(2), int64(1), str(4)
# memory usage: 27.9 MB

# %%
#we have to convert cust_id to int since id has only integers and it is currently float becuase of NaN values
df_new['cust_id'] = df_new['cust_id'].astype('int64')

# %%
df_new.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_num   406829 non-null  str
#  1   stock_code    406829 non-null  str
#  2   description   406829 non-null  str
#  3   quantity      406829 non-null  int64
#  4   invoice_date  406829 non-null  datetime64[us]
#  5   unit_price    406829 non-null  float64
#  6   cust_id       406829 non-null  int64
#  7   country       406829 non-null  str
# dtypes: datetime64[us](1), float64(1), int64(2), str(4)
# memory usage: 27.9 MB

# %%
df_new.describe()
# Out:
#             quantity                invoice_date     unit_price        cust_id
# count  406829.000000                      406829  406829.000000  406829.000000
# mean       12.061303  2011-07-10 16:30:57.879207       3.460471   15287.690570
# min    -80995.000000         2010-12-01 08:26:00       0.000000   12346.000000
# 25%         2.000000         2011-04-06 15:02:00       1.250000   13953.000000
# 50%         5.000000         2011-07-31 11:48:00       1.950000   15152.000000
# 75%        12.000000         2011-10-20 13:06:00       3.750000   16791.000000
# max     80995.000000         2011-12-09 12:50:00   38970.000000   18287.000000
# std       248.693370                         NaN      69.315162    1713.600303

# %%
df_new.describe().round(2)
# Out:
#         quantity                invoice_date  unit_price    cust_id
# count  406829.00                      406829   406829.00  406829.00
# mean       12.06  2011-07-10 16:30:57.879207        3.46   15287.69
# min    -80995.00         2010-12-01 08:26:00        0.00   12346.00
# 25%         2.00         2011-04-06 15:02:00        1.25   13953.00
# 50%         5.00         2011-07-31 11:48:00        1.95   15152.00
# 75%        12.00         2011-10-20 13:06:00        3.75   16791.00
# max     80995.00         2011-12-09 12:50:00    38970.00   18287.00
# std       248.69                         NaN       69.32    1713.60

# %%
df_new.quantity
# Out:
# 0          6
# 1          6
# 2          8
# 3          6
# 4          6
#           ..
# 541904    12
# 541905     6
# 541906     4
# 541907     4
# 541908     3
# Name: quantity, Length: 406829, dtype: int64

# %%
df_new.quantity > 0
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 541904    True
# 541905    True
# 541906    True
# 541907    True
# 541908    True
# Name: quantity, Length: 406829, dtype: bool

# %%
con = df_new.quantity>0

# %%
df_new = df_new[con]

# %%
df_new.describe().round(2)
# Out:
#         quantity                invoice_date  unit_price    cust_id
# count  397924.00                      397924   397924.00  397924.00
# mean       13.02  2011-07-10 23:43:36.912476        3.12   15294.32
# min         1.00         2010-12-01 08:26:00        0.00   12346.00
# 25%         2.00         2011-04-07 11:12:00        1.25   13969.00
# 50%         6.00         2011-07-31 14:39:00        1.95   15159.00
# 75%        12.00         2011-10-20 14:33:00        3.75   16795.00
# max     80995.00         2011-12-09 12:50:00     8142.75   18287.00
# std       180.42                         NaN       22.10    1713.17

# %%
df.shape
# Out:
# (541909, 8)

# %%
df_new.shape
# Out:
# (397924, 8)

# %%
df_new.head()
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   white hanging heart t-light holder         6
# 1      536365      71053                  white metal lantern         6
# 2      536365     84406B       cream cupid hearts coat hanger         8
# 3      536365     84029G  knitted union flag hot water bottle         6
# 4      536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  cust_id         country
# 0 2010-12-01 08:26:00        2.55    17850  United Kingdom
# 1 2010-12-01 08:26:00        3.39    17850  United Kingdom
# 2 2010-12-01 08:26:00        2.75    17850  United Kingdom
# 3 2010-12-01 08:26:00        3.39    17850  United Kingdom
# 4 2010-12-01 08:26:00        3.39    17850  United Kingdom

# %%
df_new['amount_spent'] = df_new['quantity']*df_new['unit_price']

# %%
df_new.head()
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   white hanging heart t-light holder         6
# 1      536365      71053                  white metal lantern         6
# 2      536365     84406B       cream cupid hearts coat hanger         8
# 3      536365     84029G  knitted union flag hot water bottle         6
# 4      536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  cust_id         country  amount_spent
# 0 2010-12-01 08:26:00        2.55    17850  United Kingdom         15.30
# 1 2010-12-01 08:26:00        3.39    17850  United Kingdom         20.34
# 2 2010-12-01 08:26:00        2.75    17850  United Kingdom         22.00
# 3 2010-12-01 08:26:00        3.39    17850  United Kingdom         20.34
# 4 2010-12-01 08:26:00        3.39    17850  United Kingdom         20.34

# %%
df_new.columns
# Out:
# Index(['invoice_num', 'stock_code', 'description', 'quantity', 'invoice_date',
#        'unit_price', 'cust_id', 'country', 'amount_spent'],
#       dtype='str')

# %%
#rearrange columns so that it is more readale
col_order = ['invoice_num','invoice_date', 'stock_code', 'description', 'quantity', 
       'unit_price', 'amount_spent', 'cust_id', 'country']

# %%
df_new = df_new[col_order]

# %%
df_new.head()
# Out:
#   invoice_num        invoice_date stock_code  \
# 0      536365 2010-12-01 08:26:00     85123A
# 1      536365 2010-12-01 08:26:00      71053
# 2      536365 2010-12-01 08:26:00     84406B
# 3      536365 2010-12-01 08:26:00     84029G
# 4      536365 2010-12-01 08:26:00     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom
# 2    17850  United Kingdom
# 3    17850  United Kingdom
# 4    17850  United Kingdom

# %%
len(df_new.columns)
# Out:
# 9

# %%
df_new.shape
# Out:
# (397924, 9)

# %%
#analysicing invoice date

# %%
df_new['invoice_date']
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: invoice_date, Length: 397924, dtype: datetime64[us]

# %%
df_new['invoice_date'].dt.year
# Out:
# 0         2010
# 1         2010
# 2         2010
# 3         2010
# 4         2010
#           ...
# 541904    2011
# 541905    2011
# 541906    2011
# 541907    2011
# 541908    2011
# Name: invoice_date, Length: 397924, dtype: int32

# %%
df_new['year_month'] = (df_new['invoice_date'].dt.year*100)+df_new['invoice_date'].dt.month

# %%
df_new.head()
# Out:
#   invoice_num        invoice_date stock_code  \
# 0      536365 2010-12-01 08:26:00     85123A
# 1      536365 2010-12-01 08:26:00      71053
# 2      536365 2010-12-01 08:26:00     84406B
# 3      536365 2010-12-01 08:26:00     84029G
# 4      536365 2010-12-01 08:26:00     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country  year_month
# 0    17850  United Kingdom      201012
# 1    17850  United Kingdom      201012
# 2    17850  United Kingdom      201012
# 3    17850  United Kingdom      201012
# 4    17850  United Kingdom      201012

# %%
df_new.columns
# Out:
# Index(['invoice_num', 'invoice_date', 'stock_code', 'description', 'quantity',
#        'unit_price', 'amount_spent', 'cust_id', 'country', 'year_month'],
#       dtype='str')

# %%
cols = ['invoice_num', 'year_month', 'invoice_date', 'stock_code', 'description', 'quantity',
       'unit_price', 'amount_spent', 'cust_id', 'country']

# %%
df_new = df_new[cols]

# %%
df_new.head()
# Out:
#   invoice_num  year_month        invoice_date stock_code  \
# 0      536365      201012 2010-12-01 08:26:00     85123A
# 1      536365      201012 2010-12-01 08:26:00      71053
# 2      536365      201012 2010-12-01 08:26:00     84406B
# 3      536365      201012 2010-12-01 08:26:00     84029G
# 4      536365      201012 2010-12-01 08:26:00     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom
# 2    17850  United Kingdom
# 3    17850  United Kingdom
# 4    17850  United Kingdom

# %%
cols = ['invoice_num',  'invoice_date','year_month', 'stock_code', 'description', 'quantity',
       'unit_price', 'amount_spent', 'cust_id', 'country']

# %%
df_new = df_new[cols]

# %%
df_new.head()
# Out:
#   invoice_num        invoice_date  year_month stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     85123A
# 1      536365 2010-12-01 08:26:00      201012      71053
# 2      536365 2010-12-01 08:26:00      201012     84406B
# 3      536365 2010-12-01 08:26:00      201012     84029G
# 4      536365 2010-12-01 08:26:00      201012     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom
# 2    17850  United Kingdom
# 3    17850  United Kingdom
# 4    17850  United Kingdom

# %%
c2 = 'month'

# %%
v2 = df_new['invoice_date'].dt.month

# %%
df_new.insert(loc=3,column=c2,value = v2)

# %%
df_new.head()
# Out:
#   invoice_num        invoice_date  year_month  month stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     12     85123A
# 1      536365 2010-12-01 08:26:00      201012     12      71053
# 2      536365 2010-12-01 08:26:00      201012     12     84406B
# 3      536365 2010-12-01 08:26:00      201012     12     84029G
# 4      536365 2010-12-01 08:26:00      201012     12     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom
# 2    17850  United Kingdom
# 3    17850  United Kingdom
# 4    17850  United Kingdom

# %%
c3='day'

# %%
v3 = (df_new.invoice_date.dt.dayofweek)+1

# %%
df_new.insert(loc = 4, column = c3, value = v3)

# %%
df_new.head()
# Out:
#   invoice_num        invoice_date  year_month  month  day stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     12    3     85123A
# 1      536365 2010-12-01 08:26:00      201012     12    3      71053
# 2      536365 2010-12-01 08:26:00      201012     12    3     84406B
# 3      536365 2010-12-01 08:26:00      201012     12    3     84029G
# 4      536365 2010-12-01 08:26:00      201012     12    3     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom
# 2    17850  United Kingdom
# 3    17850  United Kingdom
# 4    17850  United Kingdom

# %%
c4='hour'

# %%
v4 = df_new.invoice_date.dt.hour

# %%
df_new.insert(loc = 5, column = c4, value = v4)

# %%
df_new.head()
# Out:
#   invoice_num        invoice_date  year_month  month  day  hour stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     12    3     8     85123A
# 1      536365 2010-12-01 08:26:00      201012     12    3     8      71053
# 2      536365 2010-12-01 08:26:00      201012     12    3     8     84406B
# 3      536365 2010-12-01 08:26:00      201012     12    3     8     84029G
# 4      536365 2010-12-01 08:26:00      201012     12    3     8     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom
# 2    17850  United Kingdom
# 3    17850  United Kingdom
# 4    17850  United Kingdom

# %%
df_new.shape
# Out:
# (397924, 13)

# %%
df.shape
# Out:
# (541909, 8)

# %%
df_new.columns
# Out:
# Index(['invoice_num', 'invoice_date', 'year_month', 'month', 'day', 'hour',
#        'stock_code', 'description', 'quantity', 'unit_price', 'amount_spent',
#        'cust_id', 'country'],
#       dtype='str')

# %%
df_new.groupby(by=['cust_id']).count()
# Out:
#          invoice_num  invoice_date  year_month  month  day  hour  stock_code  \
# cust_id
# 12346              1             1           1      1    1     1           1
# 12347            182           182         182    182  182   182         182
# 12348             31            31          31     31   31    31          31
# 12349             73            73          73     73   73    73          73
# 12350             17            17          17     17   17    17          17
# ...              ...           ...         ...    ...  ...   ...         ...
# 18280             10            10          10     10   10    10          10
# 18281              7             7           7      7    7     7           7
# 18282             12            12          12     12   12    12          12
# 18283            756           756         756    756  756   756         756
# 18287             70            70          70     70   70    70          70
#
#          description  quantity  unit_price  amount_spent  country
# cust_id
# 12346              1         1           1             1        1
# 12347            182       182         182           182      182
# 12348             31        31          31            31       31
# 12349             73        73          73            73       73
# 12350             17        17          17            17       17
# ...              ...       ...         ...           ...      ...
# 18280             10        10          10            10       10
# 18281              7         7           7             7        7
# 18282             12        12          12            12       12
# 18283            756       756         756           756      756
# 18287             70        70          70            70       70
#
# [4339 rows x 12 columns]

# %%
df_new.groupby(by=['cust_id','country']).count()
# Out:
#                         invoice_num  invoice_date  year_month  month  day  \
# cust_id country
# 12346   United Kingdom            1             1           1      1    1
# 12347   Iceland                 182           182         182    182  182
# 12348   Finland                  31            31          31     31   31
# 12349   Italy                    73            73          73     73   73
# 12350   Norway                   17            17          17     17   17
# ...                             ...           ...         ...    ...  ...
# 18280   United Kingdom           10            10          10     10   10
# 18281   United Kingdom            7             7           7      7    7
# 18282   United Kingdom           12            12          12     12   12
# 18283   United Kingdom          756           756         756    756  756
# 18287   United Kingdom           70            70          70     70   70
#
#                         hour  stock_code  description  quantity  unit_price  \
# cust_id country
# 12346   United Kingdom     1           1            1         1           1
# 12347   Iceland          182         182          182       182         182
# 12348   Finland           31          31           31        31          31
# 12349   Italy             73          73           73        73          73
# 12350   Norway            17          17           17        17          17
# ...                      ...         ...          ...       ...         ...
# 18280   United Kingdom    10          10           10        10          10
# 18281   United Kingdom     7           7            7         7           7
# 18282   United Kingdom    12          12           12        12          12
# 18283   United Kingdom   756         756          756       756         756
# 18287   United Kingdom    70          70           70        70          70
#
#                         amount_spent
# cust_id country
# 12346   United Kingdom             1
# 12347   Iceland                  182
# 12348   Finland                   31
# 12349   Italy                     73
# 12350   Norway                    17
# ...                              ...
# 18280   United Kingdom            10
# 18281   United Kingdom             7
# 18282   United Kingdom            12
# 18283   United Kingdom           756
# 18287   United Kingdom            70
#
# [4347 rows x 11 columns]

# %%
df_new.groupby(by=['cust_id','country'])['invoice_num'].count()
# Out:
# cust_id  country
# 12346    United Kingdom      1
# 12347    Iceland           182
# 12348    Finland            31
# 12349    Italy              73
# 12350    Norway             17
#                           ...
# 18280    United Kingdom     10
# 18281    United Kingdom      7
# 18282    United Kingdom     12
# 18283    United Kingdom    756
# 18287    United Kingdom     70
# Name: invoice_num, Length: 4347, dtype: int64

# %%
df_new.groupby(by=['cust_id','country'], as_index = False)['invoice_num'].count()
# Out:
#       cust_id         country  invoice_num
# 0       12346  United Kingdom            1
# 1       12347         Iceland          182
# 2       12348         Finland           31
# 3       12349           Italy           73
# 4       12350          Norway           17
# ...       ...             ...          ...
# 4342    18280  United Kingdom           10
# 4343    18281  United Kingdom            7
# 4344    18282  United Kingdom           12
# 4345    18283  United Kingdom          756
# 4346    18287  United Kingdom           70
#
# [4347 rows x 3 columns]

# %%
orders = df_new.groupby(by=['cust_id','country'], as_index = False)['invoice_num'].count()

# %%
orders
# Out:
#       cust_id         country  invoice_num
# 0       12346  United Kingdom            1
# 1       12347         Iceland          182
# 2       12348         Finland           31
# 3       12349           Italy           73
# 4       12350          Norway           17
# ...       ...             ...          ...
# 4342    18280  United Kingdom           10
# 4343    18281  United Kingdom            7
# 4344    18282  United Kingdom           12
# 4345    18283  United Kingdom          756
# 4346    18287  United Kingdom           70
#
# [4347 rows x 3 columns]

# %%
orders.sort_values(by = 'invoice_num', ascending = False).head()
# Out:
#       cust_id         country  invoice_num
# 4019    17841  United Kingdom         7847
# 1888    14911            EIRE         5677
# 1298    14096  United Kingdom         5111
# 334     12748  United Kingdom         4596
# 1670    14606  United Kingdom         2700

# %% [markdown]
# # Data Visualization libraries

# %%
# !pip install matplotlib seaborn
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.11.1-cp314-cp314-win_amd64.whl.metadata (80 kB)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.28.2 (from matplotlib)
#   Downloading fonttools-4.63.0-cp314-cp314-win_amd64.whl.metadata (121 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp314-cp314-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.25 in C:\Users\naniv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (2.5.1)
# Requirement already satisfied: packaging>=20.0 in C:\Users\naniv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (26.2)
# Collecting pillow>=9 (from matplotlib)
#   Downloading pillow-12.3.0-cp314-cp314-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\naniv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in C:\Users\naniv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from seaborn) (3.0.5)
# Requirement already satisfied: tzdata in C:\Users\naniv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas>=1.2->seaborn) (2026.3)
# Requirement already satisfied: six>=1.5 in C:\Users\naniv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.11.1-cp314-cp314-win_amd64.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.5 MB 8.0 MB/s eta 0:00:02
#    ------------- -------------------------- 3.1/9.5 MB 9.0 MB/s eta 0:00:01
#    ------------------ --------------------- 4.5/9.5 MB 8.9 MB/s eta 0:00:01
#    -------------------------- ------------- 6.3/9.5 MB 8.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.1/9.5 MB 7.7 MB/s eta 0:00:01
#    -------------------------------- ------- 7.6/9.5 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.1/9.5 MB 6.0 MB/s eta 0:00:01
#    ------------------------------------ --- 8.7/9.5 MB 5.4 MB/s eta 0:00:01
#    -------------------------------------- - 9.2/9.5 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 4.6 MB/s  0:00:02
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl (232 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp314-cp314-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB 2.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.3/2.3 MB 2.6 MB/s eta 0:00:01
#    ------------------------------- -------- 1.8/2.3 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 2.5 MB/s  0:00:00
# Downloading kiwisolver-1.5.0-cp314-cp314-win_amd64.whl (75 kB)
# Downloading pillow-12.3.0-cp314-cp314-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.2 MB 3.0 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.0/7.2 MB 2.8 MB/s eta 0:00:03
#    -------- ------------------------------- 1.6/7.2 MB 2.7 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.1/7.2 MB 2.7 MB/s eta 0:00:02
#    -------------- ------------------------- 2.6/7.2 MB 2.6 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.1/7.2 MB 2.7 MB/s eta 0:00:02
#    -------------------- ------------------- 3.7/7.2 MB 2.7 MB/s eta 0:00:02
#    ------------------------ --------------- 4.5/7.2 MB 2.7 MB/s eta 0:00:02
#    --------------------------- ------------ 5.0/7.2 MB 2.7 MB/s eta 0:00:01
#    ------------------------------ --------- 5.5/7.2 MB 2.7 MB/s eta 0:00:01
#    --------------------------------- ------ 6.0/7.2 MB 2.7 MB/s eta 0:00:01
#    ------------------------------------- -- 6.8/7.2 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 2.7 MB/s  0:00:02
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
#
#    ---------------------------------------- 0/8 [pyparsing]
#    ---------------------------------------- 0/8 [pyparsing]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    -------------------- ------------------- 4/8 [cycler]
#    ------------------------- -------------- 5/8 [contourpy]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ---------------------------------------- 8/8 [seaborn]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.11.1 pillow-12.3.0 pyparsing-3.3.2 seaborn-0.13.2
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
orders = df_new.groupby(by=['cust_id','country'], as_index = False)['invoice_num'].count()
plt.subplots(figsize=(15,6))
plt.plot(orders.cust_id, orders.invoice_num)
plt.xlabel('customers ID')
plt.ylabel('Number of orders')
plt.title('Number of Orders for different customers')
plt.show()

# %%
df_new.groupby(by = ['cust_id','country'])['amount_spent'].sum()
# Out:
# cust_id  country
# 12346    United Kingdom    77183.60
# 12347    Iceland            4310.00
# 12348    Finland            1797.24
# 12349    Italy              1757.55
# 12350    Norway              334.40
#                              ...
# 18280    United Kingdom      180.60
# 18281    United Kingdom       80.82
# 18282    United Kingdom      178.05
# 18283    United Kingdom     2094.88
# 18287    United Kingdom     1837.28
# Name: amount_spent, Length: 4347, dtype: float64

# %%
money_spent = df_new.groupby(by = ['cust_id','country'], as_index = False)['amount_spent'].sum()

# %%
money_spent
# Out:
#       cust_id         country  amount_spent
# 0       12346  United Kingdom      77183.60
# 1       12347         Iceland       4310.00
# 2       12348         Finland       1797.24
# 3       12349           Italy       1757.55
# 4       12350          Norway        334.40
# ...       ...             ...           ...
# 4342    18280  United Kingdom        180.60
# 4343    18281  United Kingdom         80.82
# 4344    18282  United Kingdom        178.05
# 4345    18283  United Kingdom       2094.88
# 4346    18287  United Kingdom       1837.28
#
# [4347 rows x 3 columns]

# %%
money_spent.sort_values(by = 'amount_spent', ascending = False).head()
# Out:
#       cust_id         country  amount_spent
# 1698    14646     Netherlands     280206.02
# 4210    18102  United Kingdom     259657.30
# 3737    17450  United Kingdom     194550.79
# 3017    16446  United Kingdom     168472.50
# 1888    14911            EIRE     143825.06

# %%
money_spent = df_new.groupby(by=['cust_id', 'country'], as_index=False) ['amount_spent' ].sum()

plt.subplots (figsize=(15,6))

plt.plot (money_spent.cust_id, money_spent.amount_spent)

plt.xlabel('Customers ID')

plt.ylabel('Money spent (Dollar)')

plt.title("Money Spent for different Customers")

plt.show()

# %%
df_new.head()
# Out:
#   invoice_num        invoice_date  year_month  month  day  hour stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     12    3     8     85123A
# 1      536365 2010-12-01 08:26:00      201012     12    3     8      71053
# 2      536365 2010-12-01 08:26:00      201012     12    3     8     84406B
# 3      536365 2010-12-01 08:26:00      201012     12    3     8     84029G
# 4      536365 2010-12-01 08:26:00      201012     12    3     8     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    cust_id         country
# 0    17850  United Kingdom
# 1    17850  United Kingdom
# 2    17850  United Kingdom
# 3    17850  United Kingdom
# 4    17850  United Kingdom

# %%
color = sns.color_palette()

# %%
df_new.groupby('invoice_num')

# %%
df_new.groupby('invoice_num')['year_month']

# %%
df_new.groupby('invoice_num')['year_month'].unique()
# Out:
# invoice_num
# 536365    [201012]
# 536366    [201012]
# 536367    [201012]
# 536368    [201012]
# 536369    [201012]
#             ...
# 581583    [201112]
# 581584    [201112]
# 581585    [201112]
# 581586    [201112]
# 581587    [201112]
# Name: year_month, Length: 18536, dtype: object

# %%
df_new.groupby('invoice_num')['year_month'].unique().value_counts()
# Out:
# year_month
# [201111]    2658
# [201110]    1929
# [201109]    1756
# [201105]    1555
# [201012]    1400
# [201106]    1393
# [201107]    1331
# [201103]    1321
# [201108]    1281
# [201104]    1149
# [201102]     998
# [201101]     987
# [201112]     778
# Name: count, dtype: int64

# %%
df_new.groupby('invoice_num')['year_month'].unique().value_counts().sort_index()
# Out:
# year_month
# [201012]    1400
# [201101]     987
# [201102]     998
# [201103]    1321
# [201104]    1149
# [201105]    1555
# [201106]    1393
# [201107]    1331
# [201108]    1281
# [201109]    1756
# [201110]    1929
# [201111]    2658
# [201112]     778
# Name: count, dtype: int64

# %%
ax = df_new.groupby('invoice_num')['year_month'].unique().value_counts().sort_index().plot(kind = 'bar',color = color[0],figsize = (15,6))

ax.set_xlabel('Month and Year',fontsize=15)
ax.set_ylabel('Number of Orders',fontsize=15)
ax.set_title('Number of orders for different Months (1st Dec 2010 - 9th Dec 2011)', fontsize=15)

t = ('Dec_10','Jan_11','Feb_11','Mar_11','Apr_11','May_11','Jun_11','July_11','Aug_11','Sep_11','Oct_11','Nov_11','Dec_11')

ax.set_xticklabels(t, rotation='horizontal', fontsize=13)

plt.show()

# %%
df_new.groupby('invoice_num')

# %%
df_new.groupby('invoice_num')['day']

# %%
df_new.groupby('invoice_num')['day'].unique()
# Out:
# invoice_num
# 536365    [3]
# 536366    [3]
# 536367    [3]
# 536368    [3]
# 536369    [3]
#          ...
# 581583    [5]
# 581584    [5]
# 581585    [5]
# 581586    [5]
# 581587    [5]
# Name: day, Length: 18536, dtype: object

# %%
df_new.groupby('invoice_num')['day'].unique().value_counts()
# Out:
# day
# [4]    4033
# [3]    3455
# [2]    3185
# [1]    2863
# [5]    2831
# [7]    2169
# Name: count, dtype: int64

# %%
df_new.groupby('invoice_num')['day'].unique().value_counts().sort_index()
# Out:
# day
# [1]    2863
# [2]    3185
# [3]    3455
# [4]    4033
# [5]    2831
# [7]    2169
# Name: count, dtype: int64

# %%
ax = df_new.groupby('invoice_num')['day'].unique().value_counts().sort_index().plot(kind='bar', color=color[0], figsize=(15,6))

ax.set_xlabel('Day', fontsize=15)
ax.set_ylabel('Number of Orders', fontsize=15)
ax.set_title('Number of orders for different Days', fontsize=15)

d = ('Mon', 'Tue', 'Wed', 'Thur', 'Fri', 'Sun')

ax.set_xticklabels(d, rotation='horizontal', fontsize=15)

plt.show()

# %%
df_new.unit_price.describe()
# Out:
# count    397924.000000
# mean          3.116174
# std          22.096788
# min           0.000000
# 25%           1.250000
# 50%           1.950000
# 75%           3.750000
# max        8142.750000
# Name: unit_price, dtype: float64

# %%
#check the destribution of unit price
plt.subplots(figsize = (12,6))
sns.boxplot(df_new.unit_price)
plt.show()

# %%
 df_free = df_new[df_new.unit_price == 0]

# %%
len(df_free)
# Out:
# 40

# %%
df_free.year_month
# Out:
# 9302      201012
# 33576     201012
# 40089     201012
# 47068     201101
# 47070     201101
# 56674     201101
# 86789     201102
# 130188    201103
# 139453    201103
# 145208    201104
# 157042    201104
# 187613    201105
# 198383    201105
# 279324    201107
# 282912    201107
# 285657    201108
# 298054    201108
# 314745    201108
# 314746    201108
# 314747    201108
# 314748    201108
# 358655    201109
# 361825    201109
# 379913    201110
# 395529    201110
# 420404    201110
# 436428    201111
# 436597    201111
# 436961    201111
# 439361    201111
# 446125    201111
# 446793    201111
# 446794    201111
# 454463    201111
# 454464    201111
# 479079    201111
# 479546    201111
# 480649    201111
# 485985    201111
# 502122    201111
# Name: year_month, dtype: int32

# %%
df_free.year_month.value_counts()
# Out:
# year_month
# 201111    14
# 201108     6
# 201012     3
# 201101     3
# 201110     3
# 201103     2
# 201104     2
# 201105     2
# 201107     2
# 201109     2
# 201102     1
# Name: count, dtype: int64

# %%
df_free.year_month.value_counts().sort_index()
# Out:
# year_month
# 201012     3
# 201101     3
# 201102     1
# 201103     2
# 201104     2
# 201105     2
# 201107     2
# 201108     6
# 201109     2
# 201110     3
# 201111    14
# Name: count, dtype: int64

# %%
ax = df_free.year_month.value_counts().sort_index().plot(kind='bar', figsize=(12,6), color=color[0])

ax.set_xlabel('Month', fontsize=15)
ax.set_ylabel('Frequency', fontsize=15)
ax.set_title('Frequency for different Months (Dec 2010 - Dec 2011)', fontsize=15)

m = ('Dec_10', 'Jan_11', 'Feb_11', 'Mar_11', 'Apr_11', 'May_11', 'July_11', 'Aug_11', 'Sep_11', 'Oct_11', 'Nov_11')

ax.set_xticklabels(m, rotation='horizontal', fontsize=13)

plt.show()

# %%
df_new
# Out:
#        invoice_num        invoice_date  year_month  month  day  hour  \
# 0           536365 2010-12-01 08:26:00      201012     12    3     8
# 1           536365 2010-12-01 08:26:00      201012     12    3     8
# 2           536365 2010-12-01 08:26:00      201012     12    3     8
# 3           536365 2010-12-01 08:26:00      201012     12    3     8
# 4           536365 2010-12-01 08:26:00      201012     12    3     8
# ...            ...                 ...         ...    ...  ...   ...
# 541904      581587 2011-12-09 12:50:00      201112     12    5    12
# 541905      581587 2011-12-09 12:50:00      201112     12    5    12
# 541906      581587 2011-12-09 12:50:00      201112     12    5    12
# 541907      581587 2011-12-09 12:50:00      201112     12    5    12
# 541908      581587 2011-12-09 12:50:00      201112     12    5    12
#
#        stock_code                          description  quantity  unit_price  \
# 0          85123A   white hanging heart t-light holder         6        2.55
# 1           71053                  white metal lantern         6        3.39
# 2          84406B       cream cupid hearts coat hanger         8        2.75
# 3          84029G  knitted union flag hot water bottle         6        3.39
# 4          84029E       red woolly hottie white heart.         6        3.39
# ...           ...                                  ...       ...         ...
# 541904      22613          pack of 20 spaceboy napkins        12        0.85
# 541905      22899         children's apron dolly girl          6        2.10
# 541906      23254        childrens cutlery dolly girl          4        4.15
# 541907      23255      childrens cutlery circus parade         4        4.15
# 541908      22138        baking set 9 piece retrospot          3        4.95
#
#         amount_spent  cust_id         country
# 0              15.30    17850  United Kingdom
# 1              20.34    17850  United Kingdom
# 2              22.00    17850  United Kingdom
# 3              20.34    17850  United Kingdom
# 4              20.34    17850  United Kingdom
# ...              ...      ...             ...
# 541904         10.20    12680          France
# 541905         12.60    12680          France
# 541906         16.60    12680          France
# 541907         16.60    12680          France
# 541908         14.85    12680          France
#
# [397924 rows x 13 columns]

# %%
df_new.groupby('country')

# %%
df_new.groupby('country')['invoice_num']

# %%
df_new.groupby('country')['invoice_num'].count()
# Out:
# country
# Australia                 1185
# Austria                    398
# Bahrain                     17
# Belgium                   2031
# Brazil                      32
# Canada                     151
# Channel Islands            748
# Cyprus                     614
# Czech Republic              25
# Denmark                    380
# EIRE                      7238
# European Community          60
# Finland                    685
# France                    8342
# Germany                   9042
# Greece                     145
# Iceland                    182
# Israel                     248
# Italy                      758
# Japan                      321
# Lebanon                     45
# Lithuania                   35
# Malta                      112
# Netherlands               2363
# Norway                    1072
# Poland                     330
# Portugal                  1462
# RSA                         58
# Saudi Arabia                 9
# Singapore                  222
# Spain                     2485
# Sweden                     451
# Switzerland               1842
# USA                        179
# United Arab Emirates        68
# United Kingdom          354345
# Unspecified                244
# Name: invoice_num, dtype: int64

# %%
df_new.groupby('country')['invoice_num'].count().sort_values()
# Out:
# country
# Saudi Arabia                 9
# Bahrain                     17
# Czech Republic              25
# Brazil                      32
# Lithuania                   35
# Lebanon                     45
# RSA                         58
# European Community          60
# United Arab Emirates        68
# Malta                      112
# Greece                     145
# Canada                     151
# USA                        179
# Iceland                    182
# Singapore                  222
# Unspecified                244
# Israel                     248
# Japan                      321
# Poland                     330
# Denmark                    380
# Austria                    398
# Sweden                     451
# Cyprus                     614
# Finland                    685
# Channel Islands            748
# Italy                      758
# Norway                    1072
# Australia                 1185
# Portugal                  1462
# Switzerland               1842
# Belgium                   2031
# Netherlands               2363
# Spain                     2485
# EIRE                      7238
# France                    8342
# Germany                   9042
# United Kingdom          354345
# Name: invoice_num, dtype: int64

# %%
group_country_orders = df_new.groupby('country')['invoice_num'].count().sort_values()

# del group_country_orders['United Kingdom']

# plot number of unique customers in each country (with UK)
plt.subplots(figsize=(15,8))
group_country_orders.plot(kind='barh', fontsize=12, color=color[0])
plt.xlabel('Number of Orders', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Number of Orders for different Countries', fontsize=12)
plt.show()

# %%
group_country_orders = df_new.groupby('country')['invoice_num'].count().sort_values()

del group_country_orders['United Kingdom']

# plot number of unique customers in each country (with UK)
plt.subplots(figsize=(15,8))
group_country_orders.plot(kind='barh', fontsize=12, color=color[0])
plt.xlabel('Number of Orders', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Number of Orders for different Countries', fontsize=12)
plt.show()

# %%
#money spent by each country
df_new.groupby('country')['amount_spent'].sum()
# Out:
# country
# Australia                138521.310
# Austria                   10198.680
# Bahrain                     548.400
# Belgium                   41196.340
# Brazil                     1143.600
# Canada                     3666.380
# Channel Islands           20450.440
# Cyprus                    13590.380
# Czech Republic              826.740
# Denmark                   18955.340
# EIRE                     265545.900
# European Community         1300.250
# Finland                   22546.080
# France                   209024.050
# Germany                  228867.140
# Greece                     4760.520
# Iceland                    4310.000
# Israel                     7221.690
# Italy                     17483.240
# Japan                     37416.370
# Lebanon                    1693.880
# Lithuania                  1661.060
# Malta                      2725.590
# Netherlands              285446.340
# Norway                    36165.440
# Poland                     7334.650
# Portugal                  33439.890
# RSA                        1002.310
# Saudi Arabia                145.920
# Singapore                 21279.290
# Spain                     61577.110
# Sweden                    38378.330
# Switzerland               56443.950
# USA                        3580.390
# United Arab Emirates       1902.280
# United Kingdom          7308391.554
# Unspecified                2667.070
# Name: amount_spent, dtype: float64

# %%
df_new.groupby('country')['amount_spent'].sum().sort_values()
# Out:
# country
# Saudi Arabia                145.920
# Bahrain                     548.400
# Czech Republic              826.740
# RSA                        1002.310
# Brazil                     1143.600
# European Community         1300.250
# Lithuania                  1661.060
# Lebanon                    1693.880
# United Arab Emirates       1902.280
# Unspecified                2667.070
# Malta                      2725.590
# USA                        3580.390
# Canada                     3666.380
# Iceland                    4310.000
# Greece                     4760.520
# Israel                     7221.690
# Poland                     7334.650
# Austria                   10198.680
# Cyprus                    13590.380
# Italy                     17483.240
# Denmark                   18955.340
# Channel Islands           20450.440
# Singapore                 21279.290
# Finland                   22546.080
# Portugal                  33439.890
# Norway                    36165.440
# Japan                     37416.370
# Sweden                    38378.330
# Belgium                   41196.340
# Switzerland               56443.950
# Spain                     61577.110
# Australia                138521.310
# France                   209024.050
# Germany                  228867.140
# EIRE                     265545.900
# Netherlands              285446.340
# United Kingdom          7308391.554
# Name: amount_spent, dtype: float64

# %%
group_country_amount_spent = df_new.groupby('country')['amount_spent'].sum().sort_values()

# del group_country_amount_spent['United Kingdom']

# plot total money spent by each country (with UK)
plt.subplots(figsize=(15,8))
group_country_amount_spent.plot(kind='barh', fontsize=12, color=color[0])
plt.xlabel('Money Spent (Dollar)', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Money Spent by different Countries', fontsize=12)
plt.show()

# %%
group_country_amount_spent = df_new.groupby('country')['amount_spent'].sum().sort_values()

del group_country_amount_spent['United Kingdom']

# plot total money spent by each country (with UK)
plt.subplots(figsize=(15,8))
group_country_amount_spent.plot(kind='barh', fontsize=12, color=color[0])
plt.xlabel('Money Spent (Dollar)', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Money Spent by different Countries', fontsize=12)
plt.show()

# %% [markdown]
# # My First Data Analysis project :)
